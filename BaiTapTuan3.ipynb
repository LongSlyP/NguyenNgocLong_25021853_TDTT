# %%
#3A4
m = float(input("nhap so m:"))
n = float(input("nhap so n:"))
if n == 0:
    print("khong the chia cho 0")
else:
    lamtron = m//n
    print(f"gia tri cua m / n = {lamtron}")
# Out:
# nhap so m: 1234
# nhap so n: 2
# gia tri cua m / n = 617.0

# %%
m = float(input("nhap so m:"))
n = float(input("nhap so n:"))
if n == 0:
    print("loi khong the thuc hien phep tinh")
elif m%n == 0:
    print("gia tri cua m/n la: ",int(m/n))
elif m/n > 0:
    print("gia tri cua m/n la: ",int(m//n +1))
else:
    print("gia  tri cua m/n la: ",int(m/n))
# Out:
# nhap so m: 7
# nhap so n: -3
# gia  tri cua m/n la:  -2

# %%
while True:
    try:
        x = int(input("moi ban nhap vao so nguyen duong n: "))
        if x<= 0:
            print("day khong phai so nguyen duong , nhap lai di")
            continue
        break
    except ValueError:
        print("nhap lai di")
if x % 2  == 0:
    print("Even")
else:
    print("Odd")
# Out:
# moi ban nhap vao so nguyen duong n:  1233
# Odd

# %%
while True:
        a = str(input("nhap vao chuoi gom cac chu cai thuong cua a: "))
        b = str(input("nhap vao chuoi gom cac chu cai thuong cua b "))
        if a.isalpha() == True and b.isalpha() == True and a.islower and b.islower:
            break
        else:
            print("nhap sai dinh dang roi, nhap lai di")
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# nhap vao chuoi gom cac chu cai thuong cua a:  124s
# nhap vao chuoi gom cac chu cai thuong cua b  12ds
# nhap sai dinh dang roi, nhap lai di
# nhap vao chuoi gom cac chu cai thuong cua a:  asdwad
# nhap vao chuoi gom cac chu cai thuong cua b  asdwaf
# False

# %%
#de bai khong yeu cau tam giac vuong nen tam giac vuong = tam giac thuong
while True:
    try:
        a = int(input("moi nhap vao do dai canh a: "))
        b = int(input("moi nhap vao do dai canh b: "))
        c = int(input("moi nhap vao do dai canh c: "))
        if a <= 0 or b <= 0 or c <= 0:
            print("cac canh phai la so nguyen duong")
            continue
        break
    except ValueError:
        print("nhap lai di")
if a + b <= c or a + c <= b or b + c <= a:
    print("Khong phai tam giac")
else a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Tam giac deu")
    elif a == b  or a == c  or b == c :
        print("Tam giac can")
    else:
        print("tam giac thuong")
# Out:
# moi nhap vao do dai canh a:  3
# moi nhap vao do dai canh b:  4
# moi nhap vao do dai canh c:  5
# tam giac thuong

# %%
while True:
    try:
        n = int(input("moi nhap vao so nam hien tai: "))
        if a <= 0:
            print("n phai la so nguyen duong")
            continue
        break
    except ValueError:
        print("nhap lai di")
if n % 4 == 0 and n % 100 != 0:
    print("Yes")
elif n % 400 == 0:
    print("Yes")
else:
    print("No")
# Out:
# moi nhap vao so nam hien tai:  400
# Yes

# %%
print("---- ta co phuong trinh ax + b = 0 ----")
a = int(input("nhap gia tri cua a: "))
b = int(input("nhap gia tri cua b: "))
if a != 0:
    print(f"phuong trinh co nghiem x = {(-b/a):.2f}")
elif a == 0 and b == 0:
    print("phuong trinh co vo so nghiem")
elif a == 0 and b != 0:
    print("phuong trinh vo nghiem")
# Out:
# ---- ta co phuong trinh ax + b = 0 ----
# nhap gia tri cua a:  4
# nhap gia tri cua b:  2
# phuong trinh co nghiem x = -0.50

# %%
a = float(input("moi nhap diem cua hoc sinh: "))
if a >= 8:
    print("Gioi")
elif a >= 6.5:
    print("Kha")
elif a >= 5.0:
    print("Trung binh")
else:
    print("Yeu")
# Out:
# moi nhap diem cua hoc sinh:  6
# Trung binh

# %%
a = float(input("moi nhap vao so thuc:"))
if a % 1 == 0:
    print("ket qua lam tron len: ",a)
    print("ket qua lam tron xuong: ",a)
    print("ket qua lam tron toi so nguyen gan nhat",a)
elif a > 0:
    print("ket qua lam tron len: ",a//1 + 1 )
    print("ket qua lam tron xuong: ",a//1)
    if a -int(a) >= 0.5:
        print(f"ket qua lam tron den so nguyen gan nhat la: {a//1 + 1}")
    else:
         print(f"ket qua lam tron den so nguyen gan nhat la: {int(a)}")
else:
    print("ket qua lam tron len: ",int(a))
    print("ket qua lam tron xuong: ",a // 1)
    if a - int(a) >= -0.5:
        print(f"ket qua lam tron den so nguyen gan nhat la: {int(a)} ")
    else:
        print(f"ket qua lam tron den so nguyen gan nhat la: {a//1}")
# Out:
# moi nhap vao so thuc: -2.4
# ket qua lam tron len:  -2
# ket qua lam tron xuong:  -3.0
# ket qua lam tron den so nguyen gan nhat la: -2

# %%
a = int(input("nhap vao so a: "))
b = int(input("nhap vao so b: "))
c = int(input("nhap vao so c: "))
d = int(input("nhap vao so d: "))
if a == 0 or b % a != 0:
    print("khong tao thanh cap so nhan voi cong boi nguyen")
if b % a == 0:
    if c == b* b//a and d == c * b//a:
        print("la mot cap so nhan voi cong boi nguyen")
    else:
        print("khong phai la cap so nhan")
# Out:
# nhap vao so a:  2
# nhap vao so b:  4
# nhap vao so c:  6
# nhap vao so d:  8
# khong phai la cap so nhan

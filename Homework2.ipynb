# %%
#bai1
while True:
    try:
        x  = float(input(" moi nhap chieu dai: " ))
        y = float(input(" moi nhap chieu rong: "))
        if x < y or x < 0 or y < 0:
            print("Moi ban nhap lai so duong")
            continue
        break
    except ValueError:
        print(" nhap so di ban  " )
print("dien tich cua hcn la:", x * y)
print("chu vi cua hcn la: ", 2 * x * y)
# Out:
#  moi nhap chieu dai:  -4
#  moi nhap chieu rong:  -4
# Moi ban nhap lai so duong
#  moi nhap chieu dai:  4
#  moi nhap chieu rong:  4
# dien tich cua hcn la: 16.0
# chu vi cua hcn la:  32.0

# %%
#bai2
import math
pi = math.pi
while True:
    try:
        r = float(input(" moi nhap gia tri cua r: "))
        if r < 0:
            continue 
        break
    except ValueError:
        print("moi nhap lai gia tri: ")
print("chu vi hinh tron la: ", round(2 * pi * r,2))
print("dien tich hinh tron la: ", round(pi * r ** 2,2))
# Out:
#  moi nhap gia tri cua r:  a
# moi nhap lai gia tri:
#  moi nhap gia tri cua r:  a
# moi nhap lai gia tri:
#  moi nhap gia tri cua r:  4
# chu vi hinh tron la:  25.13
# dien tich hinh tron la:  50.27

# %%
#m
while True:
    try:
        a = float(input("moi nhap do dai canh: "))
        b = float(input("moi nhap do dai canh: "))
        c = float(input("moi nhap do dai canh: "))
        if a < 0 or b < 0 or c < 0:
            print("canh cua tam giac phai la so duong")
            continue
        break
    except:
        print(" Moi ban nhap so " )
if a + b < c and a + c < b and b + c < a :
    print(" day khong phai la tam giac " )
elif a == b == c:
    print(" day la tam giac deu " )
elif a == b != c or a == c != b or b == c != a:
    print("day la tam can")
elif a**2 == b**2 + c**2 or b**2 == a**2 + c**2 or c**2 == a**2 + b**2:
    print("day la tam giac vuong")
else:
    print("day la tam giac thuong")
# Out:
# moi nhap do dai canh:  3
# moi nhap do dai canh:  3
# moi nhap do dai canh:  4
# day la tam can

# %%
#bai4
print(''' ta co phuong trinh ax + b = 0 ''')
while True: 
    try:
        a = float(input("moi ban nhap gia tri cua a: "))
        b = float(input("moi ban nhap gia tri cua b: "))
        break
    except ValueError:
        print("moi ban thu lai " )
if a == 0 and b!= 0:
    print("phuong trinh vo nghiem ")
elif a != 0 and b == 0:
    print("nghiem cua phuong trinh la x = 0")
elif a == 0 and b == 0:
    print("phuong trinh co vo so nghiem")
else:
    print("nghiem cua phuong trinh la x = ", -b/a)
# Out:
#  ta co phuong trinh ax + b = 0
# moi ban nhap gia tri cua a:  0
# moi ban nhap gia tri cua b:  0
# phuong trinh co vo so nghiem

# %%
#bai6
while True:
    try:
        a = float(input("moi nhap gia tri cua a: " ))
        b = float(input("moi nhap gia tri cua b: "))
        c = float(input("moi nhap gia tri cua c: "))
        break
    except:
        print("moi ban nhap lai")
d = 4
print("gia tri lon nhat trong a, b , c , d la: ", max(a,b,c,d))
# Out:
# moi nhap gia tri cua a:  1
# moi nhap gia tri cua b:  2
# moi nhap gia tri cua c:  3
# gia tri lon nhat trong a, b , c , d la:  4

# %%
#bai7
while True:
    try:
        a = float(input("moi nhap gia tri cua a: " ))
        b = float(input("moi nhap gia tri cua b: "))
        c = float(input("moi nhap gia tri cua c: "))
        break
    except:
        print("moi ban nhap lai")
d = 4
print("gia tri lon nhat trong a, b , c , d la: ", min(a,b,c,d))

# %%
#bai5
print(" ta co phuong trinh ax^2 + bx + c = 0")
while True:
    try:
        a = float(input("moi nhap gia tri cua a: " ))
        b = float(input("moi nhap gia tri cua b: "))
        c = float(input("moi nhap gia tri cua c: "))
        break
    except:
        print("nhap lai gia tri")
denta = b**2 - 4*a*c
if denta < 0:
    print("phuong trinh vo nghiem")
elif a == 0 and b != 0 :
    print("phuong trinh co nghiem la x = ",-c/b)
elif a == 0 and b == 0 and c == 0:
    print("phuong trinh co vo so nghiem")
elif denta == 0:
    print("phuong trinh co nghiem kep la x = ", -b/2*a)
elif denta > 0:
    print(f"phuong trinh co nghiem la x1 = { (-b - denta**0.5)/2*a} va x2 = {(-b + denta**0.5)/2*a}")
# Out:
#  ta co phuong trinh ax^2 + bx + c = 0
# moi nhap gia tri cua a:  1
# moi nhap gia tri cua b:  8
# moi nhap gia tri cua c:  2
# phuong trinh co nghiem la x1 = -7.741657386773941 va x2 = -0.25834261322605867

# %%
#bai9
while True:
    try:
        giay = float(input("nhap vao so giay lam viec: "))
        if giay < 0:
            continue
        break
    except ValueError:
        print("moi ban nhap lai")
gio = (giay/3600) // 1
if gio == 0:
    phut = giay//60
    sogiay = giay - phut*60
    print(f"thoi gian lam viec la {gio} gio {phut} phut {sogiay}giay")
else:
    sophut = (giay % 3600) // 60
    sogiay = (giay % 3600) % 60
    print(f"thoi gian lam viec la {gio} gio {sophut} phut {sogiay}giay")
# Out:
# nhap vao so giay lam viec:  3858
# thoi gian lam viec la 1.0 gio 4.0 phut 18.0giay

# %%
#bai10
print(" ta co tam duong tron co toa do I(a,b) ban kinh r ")
print(" ta co diem A(x,y) ")

while True:
    try:
        a = float(input("moi ban nhap vao a : "))
        b = float(input("moi ban nhap vao b : "))
        r = float(input("moi ban nhap vao ban kinh r: "))
        if r <= 0:
            print("moi ban nhap lai ")
            continue
        break
    except ValueError:
        print("phai nhap so ")
while True:
    try:
        x = float(input("moi ban nhap vao x cua A: "))
        y = float(input("moi ban nhap vao y cua A: "))
        break
    except ValueError:
        print("phai nhap so: ")
IA2=(x-a)**2 + (y-b)**2
IA =IA2**0.5
if IA <= r:
    print("diem A thuoc duong tron")
else:
    print("diem A nam ngoai duong tron")
# Out:
#  ta co tam duong tron co toa do I(a,b) ban kinh r
#  ta co diem A(x,y)
# moi ban nhap vao a :  4
# moi ban nhap vao b :  5
# moi ban nhap vao ban kinh r:  4
# moi ban nhap vao x cua A:  6
# moi ban nhap vao y cua A:  7
# diem A thuoc duong tron

# %%
#bai8
print("ta co he phuong trinh ax + by = m")
print("                      cx + dy = n")
while True:
    try:
        a, b, m, c, d, n = map(float, input("moi nhap gia tri cua a b m c d n: ").split())
        break
    except ValueError:
        print("moi nhap lai")
D = a*d - b*c
Dx = m*d - b*n
Dy = a*n - c*m
if d == 0 and dx == 0 and dy == 0:
    print("phuong trinh vo so nghiem")
elif d == 0 and dx != 0 and dy != 0:
    print("he phuong trinh vo nghiem")

elif d != 0:
    print("he phuong trinh co nghiem x = ", Dx/D)
    print("                          y = ", Dy/D)
# Out:
# ta co he phuong trinh ax + by = m
#                       cx + dy = n
# moi nhap gia tri cua a b m c d n:  1 2 3 4 5 6
# he phuong trinh co nghiem x =  -1.0
#                           y =  2.0

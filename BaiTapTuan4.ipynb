# %%
#W4A1
x = 0 
for i in range(1,1001):
    x = x + i
print("tong tu 1 den n la : ",x)
# Out:
# tong tu 1 den n la :  500500

# %%
while True:
    try:
        x = int(input("moi nhap mot so nguyen duong: "))
        if x <= 0:
            print("moi nhap lai so nguyen duong")
            continue
        break
    except ValueError:
        print("phai nhap so nguyen duong")
# Out:
# moi nhap mot so nguyen duong:  4.5
# phai nhap so nguyen duong
# moi nhap mot so nguyen duong:  4.5
# phai nhap so nguyen duong
# moi nhap mot so nguyen duong:  -3
# moi nhap lai so nguyen duong
# moi nhap mot so nguyen duong:  5

# %%
n = 0
while True:
    try:
        n = int(input("moi nhap so nguyen n trong khoang 0 den 100: "))
        if 0<n<100:
            break
    except ValueError:
        print("phai nhap so nguyem ")
tich = 1
for i in range (1,n+1):
    tich = tich * i
print(f"{n}! = {tich}")
# Out:
# moi nhap so nguyen n trong khoang 0 den 100:  -4
# moi nhap so nguyen n trong khoang 0 den 100:  a
# phai nhap so nguyem
# moi nhap so nguyen n trong khoang 0 den 100:  6
# 6! = 720

# %%
x= 1
while True:
    try:
        n = int(input("moi nhap so nguyen n  "))
        break
    except ValueError:
        print("phai nhap so nguyem ")
while n // 10 != 0:
    x = x + 1
    n = n // 10
print(x)
# Out:
# moi nhap so nguyen n   1234567
# 7

# %%
while True:
    try:
        n = int(input("moi nhap so nguyen n  "))
        break
    except ValueError:
        print("phai nhap so nguyem ")
u_n = []
for i in range(n):
    a = int(input(f"moi nhap vao so nguyen thu {i+1}: "))
    u_n.append(a)
for x in range(n):
    x = u_n[x]
    if x == 42:
        print("I′ve found the meaning of life!")
        break
else:
    print("It′s a joke!")
# Out:
# moi nhap so nguyen n   5
# moi nhap vao so nguyen thu 1:  2
# moi nhap vao so nguyen thu 2:  42
# moi nhap vao so nguyen thu 3:  45
# moi nhap vao so nguyen thu 4:  32
# moi nhap vao so nguyen thu 5:  2
# I′ve found the meaning of life!

# %%
def songuyento(x):
    if x < 2:
        return False
    if x == 2:
        return True
    else:
        for i in range(2,x):
            if x%i == 0:
                return False
        return True
while True:
    try:
        a = int(input("moi ban nhap so nguyen duong a: "))
        b = int(input("moi ban nhap so nguyen duong b:"))
        if a < 0 or b < 0:
            print("moi ban nhap lai")
            continue
        break
    except ValueError:
        print("phai nhap so")
if a > b:
    a,b = b,a
print(f"ta co [{a},{b}]")
e = 0
for t in range(a,b+1):
    if songuyento(t):
        e += t
print(e)
# Out:
# moi ban nhap so nguyen duong a:  1
# moi ban nhap so nguyen duong b: 9
# ta co [1,9]
# 17

# %%
def reverse(x):
    x_rv = 0
    while x:
        x_rv = x_rv*10 + x%10
        x //= 10
    return x_rv
while True:
    try:
        n = int(input("moi ban nhap so nguyen duong n: "))
        if n <= 0 :
            print("ban nhap lai di " )
            continue
        break
    except ValueError:
        print("nhap lai di")

        
print("ta co so nguyen duong n = ",n)
print("so doi xung cua n la: ",reverse(n))
# Out:
# moi ban nhap so nguyen duong n:  123456
# ta co so nguyen duong n =  123456
# so doi xung cua n la:  654321

# %%
import math
def hamchinhphuong(x):
    s = str(x)
    return len(s) == len(set(s))
n = int(input())
sochinhphuong = []
for t in range(1,math.isqrt(n)+1):
    if hamchinhphuong(t**2):
        sochinhphuong.append(t**2)
print(*sochinhphuong)
if len(sochinhphuong) == 0:
    print(" no number")
# Out:
#  1002
# 1 4 9 16 25 36 49 64 81 169 196 256 289 324 361 529 576 625 729 784 841 961

# %%
while True:
    try:
        n = int(input("moi nhap vao so nguyen duong n : "))
        if n <= 0:
            print("nhap lai di")
            continue
        break
    except ValueError:
        print("phai nhap so nguyen duong")

max_do_dai = 0
for i in range(1,n+1):
    do_dai_day = 1
    k = i
    while k != 1:
        if k % 2 == 0:
            k = k // 2
        else:
            k = 3*k + 1
        do_dai_day += 1
    if do_dai_day > max_do_dai:
        max_do_dai = do_dai_day
        so_do = i
print("so do la",so_do)
print("co do dai day la",max_do_dai)
# Out:
# moi nhap vao so nguyen duong n :  3
# so do la 3
# co do dai day la 8

# %%
import math
while True:
    try:
        n = int(input("moi nhap vao so nguyen duong n : "))
        if n <= 0 or n >= 10**6:
            print("nhap lai di")
            continue
        break
    except ValueError:
        print("phai nhap so nguyen duong")
soluong = 0
for i in range(2,n+1):
    if n % i == 0 and i % 2 == 0:
        soluong += 1
print("so luong uoc chan la",soluong)
# Out:
# moi nhap vao so nguyen duong n :  100000
# so luong uoc chan la 30

# %%
while True:
    try:
        tien = float(input("moi nhap vao so tien tiet kiem muon gui: "))
        thang = float(input("moi nhap vao so thang muon gui: "))
        if tien < 0 or thang < 0:
            print("moi nhap lai")
            continue
        break
    except ValueError:
        print("nhap lai di")
print(f"-- ta co so tien gui tiet kiem la : {tien} dong --")
print(f"-- gui trong {thang} thang --")
print(f"-- so tien nhan duoc sau {thang} thang la {tien*(1+0.7/100)**thang} --")
# Out:
# moi nhap vao so tien tiet kiem muon gui:  12304200
# moi nhap vao so thang muon gui:  12
# -- ta co so tien gui tiet kiem la : 12304200.0 dong --
# -- gui trong 12.0 thang --
# -- so tien nhan duoc sau 12.0 thang la 13378487.846340762 --

# %% [markdown]
# ##

# %%
import math
def sothanthiet(a,b):
    uoc1 = 0
    uoc2 = 0
    bandaua = 0
    bandaub = 0
    for x in range (1,math.isqrt(a)+1):
        if a % x == 0 :
            uoc1 = x
            uoc2 = a/x
            if uoc1 == 1 or uoc1 == uoc2:
                bandaua = uoc1 + bandaua
            else:
                bandaua = uoc1 + uoc2 + bandaua
    for i in range (1,math.isqrt(b)+1):
        if b % i == 0:
            uoc1 = i
            uoc2 = b/i
            if uoc1 == 1 or uoc1 == uoc2:
                bandaub = uoc1 + bandaub
            else:
                bandaub = uoc1 + uoc2 + bandaub
    if bandaua == b and bandaub == a:
          return True
    return False
while True:
    try:
        duong1 , duong2 = map(int ,input("moi ban nhap vao 2 so nguyen duong: ").split())
        if duong1 <= 0 or duong2 <= 0 :
            print("moi nhap lai")
            continue
        break
    except ValueError:
        print("nhap lai di")
print(sothanthiet(duong1,duong2))
# Out:
# moi ban nhap vao 2 so nguyen duong:  220 284
# True

# %%
def uocchung(m,n):
    if m < n:
        m , n = n, m
    for i in range(m,0,-1):
        if m % i == 0:
            if n % i == 0:
                k = i
                break
            
    return k
while True:
    try:
        m = int(input("moi nhap so nguyen duong m: "))
        n = int(input(" moi nhap so nguyen duong n: "))
        if m <= 0 or n<= 0:
            print("nhap lai di")
            continue
        break
    except ValueError:
        print("moi ban nhap lai")
print("uoc chung lon nhat cua m va n la : ",uocchung(m,n))
# Out:
# moi nhap so nguyen duong m:  500
#  moi nhap so nguyen duong n:  230
# uoc chung lon nhat cua m va n la :  10

# %%
while True:
    try:
        tongcon = int(input("moi nhap tong so con: "))
        tongchan = int(input("moi nhap  tong so chan: "))
        if tongchan < 0 or tongcon < 0:
            print("moi ban nhap lai")
            continue
        break
    except ValueError:
        print("moi nhap lai")
cho = (tongchan - 2* tongcon)//2
ga = tongcon - cho        
if tongchan % 2 != 0:
    print("invalid")
elif  2*tongcon > tongchan or tongchan> 4*tongcon:
    print("invalid")
elif cho < 0 or ga < 0:
    print("invalid")
else:
    print("so con cho la: ",cho)
    print("so con ga la: ",ga)
# Out:
# moi nhap tong so con:  36
# moi nhap  tong so chan:  100
# so con cho la:  14
# so con ga la:  22

# %%
cho = 2
type(cho)
# Out:
# int

# %%
a,b,c = map(int, input("moi nhap gia tri cua a b c ").split())
print("gia tri cua a + b la", a + b )
# Out:
# moi nhap gia tri cua a b c  1 2 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a,b,c = map(int, input("moi nhap gia tri cua a b c "))
#       2 print("gia tri cua a + b la", a + b )
#
# ValueError: invalid literal for int() with base 10: ' '

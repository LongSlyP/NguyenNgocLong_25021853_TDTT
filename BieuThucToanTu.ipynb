# %%
#W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
a = input("Moi nhap ten: ")
print("Xin chao",a)
# Out:
# Moi nhap ten:  Le Gia Bao
# Xin chao Le Gia Bao

# %%
#W2A3
a , b = map(int, input("Moi nhap vao 2 so nguyen a va b theo lan luot:").split())
print(" a + b = ", a + b)
print(" a - b = ", a - b)
print(" a // b = ", a // b )
print(" a % b = ", a % b)
print(" a / b = ", a / b )
# Out:
# Moi nhap vao 2 so nguyen a va b theo lan luot: 6 4
#  a + b =  10
#  a - b =  2
#  a // b =  1
#  a % b =  2
#  a / b =  1.5

# %%
#W2A4
a1,b1,c1,a2,b2,a3 = map(float, input("moi nhap diem theo thu tu lan luot a1,b1,c1,a2,b2,a3: ").split())
TB = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print("Diem trung binh 8 cua hoc sinh la: ",TB)
# Out:
# moi nhap diem theo thu tu lan luot a1,b1,c1,a2,b2,a3:  8 9 8 9 8 9
# Diem trung binh 8 cua hoc sinh la:  8.6

# %%
#W2A5
a = int(input("moi nhap gia tri cua a:"))
b = int(input("moi nhap gia tri cua b:"))
print(" a**b =",a**b)
# Out:
# moi nhap gia tri cua a: 2
# moi nhap gia tri cua b: 3
#  a**b = 8

# %%
#W2A6
kytu = input("môi nhap 1 ky tu bat ky: ")

print("day la ma UNICODE cua ky tu do: ",ord(kytu))
kytu = kytu.upper()
print("chu cai in hoa cua ky tu la: ",kytu)
# Out:
# môi nhap 1 ky tu bat ky:  t
# day la ma UNICODE cua ky tu do:  116
# chu cai in hoa cua ky tu la:  T

# %%
#W2A7
A=((13**2)*3)+5
B=13**2*3 +5
print("gia tri cua A la:",A)
print("gia tri cua B la:",B)
# Out:
# gia tri cua A la: 512
# gia tri cua B la: 512

# %%
#W2A8
do_C = float(input("moi nhap vao do C: "))
F = do_C*9/5 + 32
print(f'nhiet do F la {F:.2f}')
# Out:
# moi nhap vao do C:  27
# nhiet do F la 80.60

# %%
#W2A9
dongho = float(input("hay nhap gia tri chiec dong ho ma son tung  theo USD: "))
chiphi = 10
thuexuatnhap = dongho*(30/100)
thueVAT = dongho*(10/100)
print(f'tong so tien dat phai tra la:  {dongho + chiphi + thuexuatnhap + thueVAT} USA')
# Out:
# hay nhap gia tri chiec dong ho ma son tung  theo USD:  10
# tong so tien dat phai tra la:  24.0 USA

# %%
#W2A10
a = input("moi nhap ten nguoi thu nhat:")
b = input("moi nhap ten nguoi thu hai:")
c = input("moi nhap ten nguoi thu ba:")
print(f'Hi {c} , {b} va {a}')
# Out:
# moi nhap ten nguoi thu nhat: Le
# moi nhap ten nguoi thu hai: Gia
# moi nhap ten nguoi thu ba: Bao
# Hi Bao , Gia va Le

# %%
#W2A11
a = float(input("moi nhap vao gio:"))
b = float(input("moi nhap vao phut:"))
giogiay = a * 3600
phutgiay = b * 60
print(f' {a} gio = {giogiay} giay , {b} phut = {phutgiay} giay')
# Out:
# moi nhap vao gio: 1
# moi nhap vao phut: 30
#  1.0 gio = 3600.0 giay , 30.0 phut = 1800.0 giay

# %%
#2A12
dodaicanh = int(input("moi nhap vao do dai canh cua rubik: "))
print(f'khoi rubik can {dodaicanh*6 :.0f} mieng danh rieng le')
# Out:
# moi nhap vao do dai canh cua rubik:  4
# khoi rubik can 24 mieng danh rieng le

# %%
#2A13
a , b = map(int, input("moi nhap vao 2 so nguyen duong a va b:").split())
tichab = a* b
print("hang don vi cua tich a va b la: ", tichab % 10)
# Out:
# moi nhap vao 2 so nguyen duong a va b: 6 80
# hang don vi cua tich a va b la:  0

# %%
#2A14
a,b = map(float , input("moi nhap vao 2 gia tri cua a va b: ").split())
a,b = b,a
print(f'gia tri cua a la {a}, gia tri cua b la {b}')
# Out:
# moi nhap vao 2 gia tri cua a va b:  20 10
# gia tri cua a la 10.0, gia tri cua b la 20.0

# %%
#2A15
n = float(input("moi nhap vao so sao: "))
print("so sao thu n la: ",6*n*(n-1)+1)
# Out:
# moi nhap vao so sao:  2
# so sao thu n la:  13.0

# %%
#2A16
print("Spring\nSummer\nAutumn\nWinter")
print('''         Spring
         Summer
         Autumn
         Winter''')
# Out:
# Spring
# Summer
# Autumn
# Winter
#          Spring
#          Summer
#          Autumn
#          Winter

# %%
#2A17
print("       *       ")
print("      * *      ")
print("     * * *     ")
# Out:
#        *
#       * *
#      * * *

# %%
#2A18
print("###  # #     ###  ###")
print(" #   #   #    #    # ")
print(" #   #   #    #    # ")
print(" #   # #      #    #")
# Out:
# ###  # #     ###  ###
#  #   #   #    #    #
#  #   #   #    #    #
#  #   # #      #    #

# %%
#2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September

# %%
#W2A21
for i in range(11):
    print("Hello,world")
# Out:
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
